# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting appdirs==1.4.4 (from -r ./requirements.txt (line 1))
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting funcy==2.0 (from -r ./requirements.txt (line 2))
#   Downloading funcy-2.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting pydrive2==1.21.3 (from -r ./requirements.txt (line 3))
#   Downloading PyDrive2-1.21.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting phonenumbers (from -r ./requirements.txt (line 4))
#   Downloading phonenumbers-9.0.6-py2.py3-none-any.whl.metadata (11 kB)
# Collecting anthropic==0.52.2 (from -r ./requirements.txt (line 5))
#   Downloading anthropic-0.52.2-py3-none-any.whl.metadata (25 kB)
# Collecting sqlmodel==0.0.24 (from -r ./requirements.txt (line 6))
#   Downloading sqlmodel-0.0.24-py3-none-any.whl.metadata (10 kB)
# Collecting google-api-python-client>=1.12.5 (from pydrive2==1.21.3->-r ./requirements.txt (line 3))
#   Downloading google_api_python_client-2.171.0.tar.gz (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 29.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting oauth2client>=4.0.0 (from pydrive2==1.21.3->-r ./requirements.txt (line 3))
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting PyYAML>=3.0 (from pydrive2==1.21.3->-r ./requirements.txt (line 3))
#   Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: cryptography<44 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from pydrive2==1.21.3->-r ./requirements.txt (line 3)) (43.0.0)
# Requirement already satisfied: pyOpenSSL<=24.2.1,>=19.1.0 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from pydrive2==1.21.3->-r ./requirements.txt (line 3)) (24.2.1)
# Collecting anyio<5,>=3.5.0 (from anthropic==0.52.2->-r ./requirements.txt (line 5))
#   Downloading anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting distro<2,>=1.7.0 (from anthropic==0.52.2->-r ./requirements.txt (line 5))
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.25.0 (from anthropic==0.52.2->-r ./requirements.txt (line 5))
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from anthropic==0.52.2->-r ./requirements.txt (line 5))
#   Downloading jiter-0.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting pydantic<3,>=1.9.0 (from anthropic==0.52.2->-r ./requirements.txt (line 5))
#   Downloading pydantic-2.11.5-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 1.2 MB/s eta 0:00:00
# Collecting sniffio (from anthropic==0.52.2->-r ./requirements.txt (line 5))
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from anthropic==0.52.2->-r ./requirements.txt (line 5)) (4.13.2)
# Requirement already satisfied: SQLAlchemy<2.1.0,>=2.0.14 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from sqlmodel==0.0.24->-r ./requirements.txt (line 6)) (2.0.40)
# Requirement already satisfied: idna>=2.8 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from anyio<5,>=3.5.0->anthropic==0.52.2->-r ./requirements.txt (line 5)) (3.8)
# Requirement already satisfied: cffi>=1.12 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from cryptography<44->pydrive2==1.21.3->-r ./requirements.txt (line 3)) (1.17.0)
# Collecting httplib2<1.0.0,>=0.19.0 (from google-api-python-client>=1.12.5->pydrive2==1.21.3->-r ./requirements.txt (line 3))
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from google-api-python-client>=1.12.5->pydrive2==1.21.3->-r ./requirements.txt (line 3)) (2.34.0)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client>=1.12.5->pydrive2==1.21.3->-r ./requirements.txt (line 3))
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from google-api-python-client>=1.12.5->pydrive2==1.21.3->-r ./requirements.txt (line 3)) (2.19.2)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client>=1.12.5->pydrive2==1.21.3->-r ./requirements.txt (line 3))
#   Downloading uritemplate-4.2.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: certifi in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from httpx<1,>=0.25.0->anthropic==0.52.2->-r ./requirements.txt (line 5)) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.25.0->anthropic==0.52.2->-r ./requirements.txt (line 5))
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.25.0->anthropic==0.52.2->-r ./requirements.txt (line 5))
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: pyasn1>=0.1.7 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from oauth2client>=4.0.0->pydrive2==1.21.3->-r ./requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from oauth2client>=4.0.0->pydrive2==1.21.3->-r ./requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: rsa>=3.1.4 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from oauth2client>=4.0.0->pydrive2==1.21.3->-r ./requirements.txt (line 3)) (4.9)
# Requirement already satisfied: six>=1.6.1 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from oauth2client>=4.0.0->pydrive2==1.21.3->-r ./requirements.txt (line 3)) (1.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->anthropic==0.52.2->-r ./requirements.txt (line 5))
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3,>=1.9.0->anthropic==0.52.2->-r ./requirements.txt (line 5))
#   Downloading pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3,>=1.9.0->anthropic==0.52.2->-r ./requirements.txt (line 5))
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: greenlet>=1 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from SQLAlchemy<2.1.0,>=2.0.14->sqlmodel==0.0.24->-r ./requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: pycparser in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from cffi>=1.12->cryptography<44->pydrive2==1.21.3->-r ./requirements.txt (line 3)) (2.22)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2==1.21.3->-r ./requirements.txt (line 3)) (1.65.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2==1.21.3->-r ./requirements.txt (line 3)) (4.25.4)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2==1.21.3->-r ./requirements.txt (line 3)) (1.24.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2==1.21.3->-r ./requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=1.12.5->pydrive2==1.21.3->-r ./requirements.txt (line 3)) (5.5.0)
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 (from httplib2<1.0.0,>=0.19.0->google-api-python-client>=1.12.5->pydrive2==1.21.3->-r ./requirements.txt (line 3))
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2==1.21.3->-r ./requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /toolkit-cache/0.2.21/python3.11/kernel-libs/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2==1.21.3->-r ./requirements.txt (line 3)) (1.26.20)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Downloading PyDrive2-1.21.3-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 1.9 MB/s eta 0:00:00
# Downloading anthropic-0.52.2-py3-none-any.whl (286 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.3/286.3 kB 10.7 MB/s eta 0:00:00
# Downloading sqlmodel-0.0.24-py3-none-any.whl (28 kB)
# Downloading phonenumbers-9.0.6-py2.py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 41.3 MB/s eta 0:00:00
# Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 kB 6.7 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 5.7 MB/s eta 0:00:00
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 2.5 MB/s eta 0:00:00
# Downloading jiter-0.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (352 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.2/352.2 kB 15.2 MB/s eta 0:00:00
# Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 4.4 MB/s eta 0:00:00
# Downloading pydantic-2.11.5-py3-none-any.whl (444 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.2/444.2 kB 31.9 MB/s eta 0:00:00
# Downloading pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 67.3 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 45.4 MB/s eta 0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 2.6 MB/s eta 0:00:00
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 12.3 MB/s eta 0:00:00
# Building wheels for collected packages: google-api-python-client
#   Building wheel for google-api-python-client (setup.py): started
#   Building wheel for google-api-python-client (setup.py): finished with status 'done'
#   Created wheel for google-api-python-client: filename=google_api_python_client-2.171.0-py3-none-any.whl size=13547267 sha256=e0e7d4381cd2265690f606af4a1dfa7db8664a66dcc6c8f9df74c2334cf5203b
#   Stored in directory: /root/.cache/pip/wheels/07/ce/18/c124337db05d2e490b0820fcd984264bf3d7ef8c11f1dab434
# Successfully built google-api-python-client
# Installing collected packages: phonenumbers, funcy, appdirs, uritemplate, typing-inspection, sniffio, PyYAML, pyparsing, pydantic-core, jiter, h11, distro, annotated-types, pydantic, httplib2, httpcore, anyio, sqlmodel, oauth2client, httpx, google-auth-httplib2, google-api-python-client, anthropic, pydrive2
# Successfully installed PyYAML-6.0.2 annotated-types-0.7.0 anthropic-0.52.2 anyio-4.9.0 appdirs-1.4.4 distro-1.9.0 funcy-2.0 google-api-python-client-2.171.0 google-auth-httplib2-0.2.0 h11-0.16.0 httpcore-1.0.9 httplib2-0.22.0 httpx-0.28.1 jiter-0.10.0 oauth2client-4.1.3 phonenumbers-9.0.6 pydantic-2.11.5 pydantic-core-2.33.2 pydrive2-1.21.3 pyparsing-3.2.3 sniffio-1.3.1 sqlmodel-0.0.24 typing-inspection-0.4.1 uritemplate-4.2.0
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=396ab0e0-a72e-4b1a-9734-fd5f14f23ea1' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
